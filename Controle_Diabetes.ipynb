# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidWillian91/alurabooks/blob/aula01/Controle_Diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

notas = pd.read_excel("controle_diabete.xls")

# %%
notas.head()
# Out:
#    Dia da semana        Data  Tempo                    Título    Glicose  \
# 0        domingo  17.03.2024  09:00    Antes do café da manhã  241 mg/dl
# 1        domingo  17.03.2024  13:12  2 horas depois do almoço  242 mg/dl
# 2        domingo  17.03.2024  16:46  2 horas depois do almoço  219 mg/dl
# 3        domingo  17.03.2024  20:09           Antes do jantar  189 mg/dl
# 4  segunda-feira  18.03.2024  05:52    Antes do café da manhã  174 mg/dl
#
#    Descrição
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
notas.Glicose
# Out:
# 0      241 mg/dl
# 1      242 mg/dl
# 2      219 mg/dl
# 3      189 mg/dl
# 4      174 mg/dl
# 5      263 mg/dl
# 6       94 mg/dl
# 7      308 mg/dl
# 8      308 mg/dl
# 9      158 mg/dl
# 10      82 mg/dl
# 11     146 mg/dl
# 12     168 mg/dl
# 13     169 mg/dl
# 14     163 mg/dl
# 15     211 mg/dl
# 16     149 mg/dl
# 17     343 mg/dl
# 18     395 mg/dl
# 19     305 mg/dl
# 20     317 mg/dl
# 21     181 mg/dl
# 22     219 mg/dl
# 23     211 mg/dl
# 24     261 mg/dl
# 25     248 mg/dl
# 26     210 mg/dl
# 27     328 mg/dl
# 28     433 mg/dl
# 29     217 mg/dl
# 30     338 mg/dl
# 31     208 mg/dl
# 32     331 mg/dl
# 33     149 mg/dl
# 34     211 mg/dl
# 35      98 mg/dl
# 36     252 mg/dl
# 37     154 mg/dl
# 38     361 mg/dl
# 39     180 mg/dl
# 40     370 mg/dl
# 41     129 mg/dl
# 42     249 mg/dl
# 43     200 mg/dl
# 44     276 mg/dl
# 45     266 mg/dl
# 46     266 mg/dl
# 47     200 mg/dl
# 48     308 mg/dl
# 49     203 mg/dl
# 50     223 mg/dl
# 51     299 mg/dl
# ...

# %%
notas.Glicose.unique()
# Out:
# array(['241 mg/dl', '242 mg/dl', '219 mg/dl', '189 mg/dl', '174 mg/dl',
#        '263 mg/dl', '94 mg/dl', '308 mg/dl', '158 mg/dl', '82 mg/dl',
#        '146 mg/dl', '168 mg/dl', '169 mg/dl', '163 mg/dl', '211 mg/dl',
#        '149 mg/dl', '343 mg/dl', '395 mg/dl', '305 mg/dl', '317 mg/dl',
#        '181 mg/dl', '261 mg/dl', '248 mg/dl', '210 mg/dl', '328 mg/dl',
#        '433 mg/dl', '217 mg/dl', '338 mg/dl', '208 mg/dl', '331 mg/dl',
#        '98 mg/dl', '252 mg/dl', '154 mg/dl', '361 mg/dl', '180 mg/dl',
#        '370 mg/dl', '129 mg/dl', '249 mg/dl', '200 mg/dl', '276 mg/dl',
#        '266 mg/dl', '203 mg/dl', '223 mg/dl', '299 mg/dl', '246 mg/dl',
#        '135 mg/dl', '224 mg/dl', '280 mg/dl', '236 mg/dl', '468 mg/dl',
#        '408 mg/dl', '226 mg/dl', '279 mg/dl', '188 mg/dl', '84 mg/dl',
#        '391 mg/dl', '119 mg/dl', '142 mg/dl', '199 mg/dl', '186 mg/dl',
#        '510 mg/dl', '214 mg/dl', '253 mg/dl', '101 mg/dl', '459 mg/dl',
# ...

# %%
notas.Glicose.value_counts()
# Out:
# Glicose
# 154 mg/dl    3
# 308 mg/dl    3
# 299 mg/dl    3
# 211 mg/dl    3
# 149 mg/dl    2
# 295 mg/dl    2
# 254 mg/dl    2
# 249 mg/dl    2
# 200 mg/dl    2
# 266 mg/dl    2
# 250 mg/dl    2
# 248 mg/dl    2
# 246 mg/dl    2
# 135 mg/dl    2
# 224 mg/dl    2
# 142 mg/dl    2
# 219 mg/dl    2
# 189 mg/dl    2
# 324 mg/dl    1
# 320 mg/dl    1
# 287 mg/dl    1
# 291 mg/dl    1
# 510 mg/dl    1
# 214 mg/dl    1
# 253 mg/dl    1
# 257 mg/dl    1
# 101 mg/dl    1
# 459 mg/dl    1
# 384 mg/dl    1
# 244 mg/dl    1
# 293 mg/dl    1
# 312 mg/dl    1
# 347 mg/dl    1
# 241 mg/dl    1
# 77 mg/dl     1
# 333 mg/dl    1
# 110 mg/dl    1
# 195 mg/dl    1
# 229 mg/dl    1
# 166 mg/dl    1
# 89 mg/dl     1
# 345 mg/dl    1
# 81 mg/dl     1
# 277 mg/dl    1
# 234 mg/dl    1
# 185 mg/dl    1
# 297 mg/dl    1
# 141 mg/dl    1
# 201 mg/dl    1
# 127 mg/dl    1
# 281 mg/dl    1
# 274 mg/dl    1
# 240 mg/dl    1
# 283 mg/dl    1
# 233 mg/dl    1
# 162 mg/dl    1
# 186 mg/dl    1
# 288 mg/dl    1
# ...

# %%
notas.Glicose.head()
# Out:
# 0    241 mg/dl
# 1    242 mg/dl
# 2    219 mg/dl
# 3    189 mg/dl
# 4    174 mg/dl
# Name: Glicose, dtype: object

# %%
notas.Glicose.describe()
# Out:
# count           124
# unique          102
# top       154 mg/dl
# freq              3
# Name: Glicose, dtype: object

# %%
import seaborn as sns

sns.boxplot(notas.Glicose)
# Out:
# <Axes: ylabel='Glicose'>

# %%
pd.set_option('display.max_rows', None)
